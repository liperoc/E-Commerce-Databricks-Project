# %%
#Bronze Layer

bronze_df = (
    spark.read
    .option("header", True)
    .option("inferSchema", True)
    .csv("/Volumes/workspace/default/e-commerce-data/data.csv")
)

bronze_df.write \
    .format("delta") \
    .mode("overwrite") \
    .save("/Volumes/workspace/default/e-commerce-data/bronze")
